# %%
import pandas as pd
import numpy as np
import os

# %%
sourcePath = r"C:\coding\leetcode-company-wise-problems"

# %%
dirList = []
for name in os.listdir(sourcePath):
    path = f"{sourcePath}\\{name}"
    if os.path.isdir(path):
        dirList.append(path)
del dirList[:4]
dirList[0]
# Out:
# 'C:\\coding\\leetcode-company-wise-problems\\Accenture'

# %%
def processCompanyProblems(dirList):
    allData = []
    for path in dirList:
        companyName = os.path.basename(path)
        try:
            tempDf = pd.read_csv(f"{path}\\5. All.csv")
            tempDf['Company'] = companyName
            allData.append(tempDf)
            print(f"Processed {companyName}: {len(tempDf)} problems")
        except FileNotFoundError:
            print(f"File not found for {companyName}")
            continue

    if allData:
        combinedDf = pd.concat(allData, axis=0, ignore_index=True)
        print(f"Total problems before dedup: {len(combinedDf)}")
        return combinedDf
    else:
        return pd.Dataframe()

# %%
def create_final_result_with_difficulty_sort(combined_df):
    """
    Create final result with proper difficulty sorting (Easy -> Medium -> Hard)
    """
    # Group by Title to get all companies for each problem
    problem_companies = combined_df.groupby('Title')['Company'].apply(
        lambda x: sorted(list(set(x)))  # Sort companies alphabetically
    ).reset_index()
    problem_companies.columns = ['Title', 'Companies']
    
    # Get unique problem details
    unique_problems = combined_df.drop_duplicates(subset=['Title']).copy()
    
    # Merge companies back
    unique_problems = unique_problems.merge(problem_companies, on='Title', how='left')
    
    # Create difficulty ranking
    difficulty_order = {'EASY': 1, 'MEDIUM': 2, 'HARD': 3}
    unique_problems['difficulty_rank'] = unique_problems['Difficulty'].map(difficulty_order)
    
    # Create expanded dataframe for each topic
    final_rows = []
    
    for idx, row in unique_problems.iterrows():
        if pd.notna(row['Topics']):
            topics = [topic.strip() for topic in row['Topics'].split(',')]
            
            for topic in topics:
                final_rows.append({
                    'Problem_Type': topic,
                    'Companies': ', '.join(row['Companies']),  # Join as string
                    'Company_List': row['Companies'],  # Keep as list for analysis
                    'Company_Count': len(row['Companies']),
                    'Title': row['Title'],
                    'Difficulty': row['Difficulty'],
                    'difficulty_rank': row['difficulty_rank'],  # Add ranking for sorting
                    'Frequency': row['Frequency'],
                    'Acceptance_Rate': row['Acceptance Rate'],
                    'Link': row['Link']
                })
    
    finalDf = pd.DataFrame(final_rows)
    
    # Sort by Problem Type, then by difficulty (Easy->Medium->Hard), then by Company Count (descending), then by Frequency
    finalDf = finalDf.sort_values(['Problem_Type', 'difficulty_rank', 'Company_Count', 'Frequency'], 
                                   ascending=[True, True, False, False])
    
    # Remove the helper column
    finalDf = finalDf.drop('difficulty_rank', axis=1)
    
    return finalDf

# %%
print("Processing company directories...")
combined_df = processCompanyProblems(dirList)

if not combined_df.empty:
    print(f"Creating final result...")
    final_result = create_final_result_with_difficulty_sort(combined_df)
    
    print(f"Final result: {len(final_result)} rows")
    
    # Display sample results
    print("\nSample results:")
    print(final_result.head(10))
    
    # Save to CSV if needed
    final_result.to_csv('leetcode_problems_by_type_and_company.csv', index=False)
    print("Results saved to 'leetcode_problems_by_type_and_company.csv'")
# Out:
# Processing company directories...
# Processed Accenture: 100 problems
# Processed Accolite: 17 problems
# Processed Acko: 4 problems
# Processed Activision: 3 problems
# Processed Adobe: 100 problems
# Processed Affirm: 11 problems
# Processed Agoda: 40 problems
# Processed Airbnb: 58 problems
# Processed Airbus SE: 5 problems
# Processed Airtel: 6 problems
# Processed Airwallex: 1 problems
# Processed Akamai: 7 problems
# Processed Akuna Capital: 23 problems
# Processed Alibaba: 5 problems
# Processed Altimetrik: 4 problems
# Processed Amadeus: 4 problems
# Processed Amazon: 100 problems
# Processed AMD: 11 problems
# Processed Amdocs: 7 problems
# Processed American Express: 23 problems
# Processed Analytics quotient: 2 problems
# Processed Anduril: 32 problems
# Processed Aon: 4 problems
# Processed Apollo.io: 4 problems
# Processed AppDynamics: 2 problems
# Processed AppFolio: 4 problems
# Processed Apple: 100 problems
# Processed Applied Intuition: 12 problems
# Processed AQR Capital Management: 3 problems
# Processed Arcesium: 20 problems
# Processed Arista Networks: 38 problems
# Processed Asana: 3 problems
# Processed athenahealth: 11 problems
# Processed Atlassian: 73 problems
# Processed Attentive: 9 problems
# Processed Audible: 3 problems
# Processed Aurora: 4 problems
# Processed Autodesk: 31 problems
# Processed Avalara: 2 problems
# Processed Avito: 9 problems
# Processed Axon: 7 problems
# Processed Baidu: 10 problems
# Processed Bank of America: 3 problems
# Processed Barclays: 18 problems
# Processed Bentley Systems: 2 problems
# Processed BharatPe: 2 problems
# Processed BILL Holdings: 1 problems
# Processed BitGo: 10 problems
# Processed BlackRock: 17 problems
# Processed BlackStone: 2 problems
# Processed blinkit: 2 problems
# Processed Blizzard: 2 problems
# Processed Block: 14 problems
# Processed Bloomberg: 100 problems
# Processed BNY Mellon: 21 problems
# Processed Bolt: 7 problems
# Processed Booking.com: 16 problems
# Processed Bosch: 2 problems
# Processed Box: 6 problems
# Processed BP: 4 problems
# Processed Braze: 3 problems
# Processed Brex: 0 problems
# Processed Bridgewater Associates: 2 problems
# Processed ByteDance: 64 problems
# Processed Cadence: 6 problems
# Processed Canonical: 3 problems
# Processed Capgemini: 25 problems
# Processed Capital One: 47 problems
# Processed Careem: 3 problems
# Processed CARS24: 8 problems
# Processed carwale: 5 problems
# Processed Cashfree: 3 problems
# Processed CEDCOSS: 4 problems
# Processed Celigo: 2 problems
# Processed Chewy: 6 problems
# Processed Chime: 2 problems
# Processed ciena: 2 problems
# Processed Circle: 2 problems
# Processed Cisco: 87 problems
# Processed Citadel: 100 problems
# Processed Citigroup: 3 problems
# Processed Citrix: 7 problems
# Processed Clari: 3 problems
# Processed Cleartrip: 4 problems
# Processed Cloudera: 5 problems
# Processed Cloudflare: 10 problems
# Processed CME Group: 2 problems
# Processed Coforge: 0 problems
# Processed Cognizant: 29 problems
# Processed Cohesity: 3 problems
# Processed Coinbase: 12 problems
# Processed Comcast: 4 problems
# Processed Commvault: 11 problems
# Processed Compass: 6 problems
# Processed Confluent: 12 problems
# Processed ConsultAdd: 11 problems
# Processed Coupang: 49 problems
# Processed Coursera: 11 problems
# Processed Coveo: 2 problems
# Processed CRED: 2 problems
# Processed Credit Karma: 0 problems
# Processed Criteo: 8 problems
# Processed CrowdStrike: 11 problems
# Processed Cruise: 6 problems
# Processed CTC: 1 problems
# Processed CureFit: 3 problems
# Processed CVENT: 2 problems
# Processed Darwinbox: 5 problems
# Processed Databricks: 34 problems
# Processed Datadog: 20 problems
# Processed Dataminr: 2 problems
# Processed DE Shaw: 100 problems
# Processed Delhivery: 3 problems
# Processed Deliveroo: 5 problems
# Processed Dell: 7 problems
# Processed Deloitte: 27 problems
# Processed DeltaX: 3 problems
# Processed Deutsche Bank: 30 problems
# Processed DevRev: 4 problems
# Processed Devsinc: 2 problems
# Processed Devtron: 2 problems
# Processed Directi: 9 problems
# Processed Disney: 19 problems
# Processed Docusign: 34 problems
# Processed DoorDash: 88 problems
# Processed DP world: 7 problems
# Processed Dream11: 11 problems
# Processed Dropbox: 25 problems
# Processed Druva: 4 problems
# Processed DRW: 9 problems
# Processed Dunzo: 8 problems
# Processed Duolingo: 4 problems
# Processed DXC Technology: 3 problems
# Processed EarnIn: 4 problems
# Processed eBay: 78 problems
# Processed Edelweiss Group: 1 problems
# Processed Electronic Arts: 3 problems
# Processed EPAM Systems: 43 problems
# Processed Epic Systems: 12 problems
# Processed Expedia: 49 problems
# Processed EY: 3 problems
# Processed FactSet: 5 problems
# Processed Faire: 3 problems
# Processed Fastenal: 4 problems
# Processed Fidelity: 3 problems
# Processed Fiverr: 2 problems
# Processed Flexera: 2 problems
# Processed Flexport: 10 problems
# Processed Flipkart: 100 problems
# Processed Fortinet: 4 problems
# Processed fourkites: 3 problems
# Processed FPT: 4 problems
# Processed Freecharge: 3 problems
# Processed FreshWorks: 9 problems
# Processed Gameskraft: 4 problems
# Processed Garmin: 6 problems
# Processed GE Digital: 3 problems
# Processed GE Healthcare: 7 problems
# Processed Geico: 20 problems
# Processed General Motors: 8 problems
# Processed Genpact: 3 problems
# Processed GoDaddy: 0 problems
# Processed Gojek: 5 problems
# Processed Goldman Sachs: 100 problems
# Processed Google: 100 problems
# Processed Grab: 13 problems
# Processed Grammarly: 27 problems
# Processed Graviton: 7 problems
# Processed Groupon: 4 problems
# Processed Groww: 8 problems
# Processed Grubhub: 2 problems
# Processed GSA Capital: 2 problems
# Processed GSN Games: 5 problems
# Processed Guidewire: 6 problems
# Processed Gusto: 3 problems
# Processed Harness: 1 problems
# Processed HashedIn: 23 problems
# Processed HCL: 9 problems
# Processed Hertz: 2 problems
# Processed Highspot: 2 problems
# Processed HiLabs: 3 problems
# Processed Hive: 2 problems
# Processed Hiver: 2 problems
# Processed Honeywell: 4 problems
# Processed Hotstar: 3 problems
# Processed Houzz: 2 problems
# Processed HP: 3 problems
# Processed HPE: 4 problems
# Processed HSBC: 4 problems
# Processed Huawei: 15 problems
# Processed Hubspot: 10 problems
# Processed Hudson River Trading: 9 problems
# Processed Hulu: 5 problems
# Processed IBM: 100 problems
# Processed IIT Bombay: 2 problems
# Processed IMC: 8 problems
# Processed Indeed: 7 problems
# Processed INDmoney: 2 problems
# Processed Info Edge: 7 problems
# Processed Informatica: 3 problems
# Processed Infosys: 100 problems
# Processed InMobi: 6 problems
# Processed instabase: 2 problems
# Processed Instacart: 15 problems
# Processed Intel: 25 problems
# Processed Intuit: 73 problems
# Processed IVP: 2 problems
# Processed IXL: 17 problems
# Processed J.P. Morgan: 79 problems
# Processed Jane Street: 11 problems
# Processed jio: 7 problems
# Processed josh technology: 22 problems
# Processed Jump Trading: 6 problems
# Processed Juniper Networks: 3 problems
# Processed Juspay: 11 problems
# Processed Kakao: 2 problems
# Processed Karat: 15 problems
# Processed KLA: 8 problems
# Processed Komprise: 2 problems
# Processed Larsen & Toubro: 2 problems
# Processed Lendingkart Technologies: 1 problems
# Processed Lenskart: 2 problems
# Processed Licious: 2 problems
# Processed Liftoff: 4 problems
# Processed LINE: 4 problems
# Processed LinkedIn: 100 problems
# Processed LiveRamp: 6 problems
# Processed Lowe's: 4 problems
# Processed LTI: 4 problems
# Processed Lucid: 8 problems
# Processed Luxoft: 2 problems
# Processed Lyft: 26 problems
# Processed Machine Zone: 2 problems
# Processed MakeMyTrip: 29 problems
# Processed Mapbox: 2 problems
# Processed MAQ Software: 5 problems
# Processed Mastercard: 12 problems
# Processed MathWorks: 29 problems
# Processed McKinsey: 4 problems
# Processed Media.net: 39 problems
# Processed Meesho: 0 problems
# Processed Mercari: 5 problems
# Processed Meta: 100 problems
# Processed Microsoft: 100 problems
# Processed Microstrategy: 9 problems
# Processed Millennium: 7 problems
# Processed Mindtickle: 4 problems
# Processed MindTree: 3 problems
# Processed Miro: 3 problems
# Processed Mitsogo: 16 problems
# Processed Mixpanel: 3 problems
# Processed Mobileye: 2 problems
# Processed Moengage: 2 problems
# Processed Moloco: 7 problems
# Processed MongoDB: 14 problems
# Processed Morgan Stanley: 51 problems
# Processed Mountblue: 2 problems
# Processed Moveworks: 6 problems
# Processed MSCI: 1 problems
# Processed Myntra: 22 problems
# Processed Nagarro: 9 problems
# Processed National Instruments: 4 problems
# Processed National Payments Corporation of India: 2 problems
# Processed Navan: 4 problems
# Processed Navi: 4 problems
# Processed NCR: 2 problems
# Processed NetApp: 10 problems
# Processed NetEase: 2 problems
# Processed Netflix: 38 problems
# Processed Netskope: 3 problems
# Processed Netsuite: 2 problems
# Processed Nextdoor: 8 problems
# Processed Niantic: 5 problems
# Processed Nielsen: 6 problems
# Processed Nike: 10 problems
# Processed NinjaCart: 1 problems
# Processed Nokia: 6 problems
# Processed Nordstrom: 10 problems
# Processed Notion: 3 problems
# Processed Nuro: 9 problems
# Processed Nutanix: 60 problems
# Processed Nvidia: 100 problems
# Processed Nykaa: 5 problems
# Processed Odoo: 5 problems
# Processed Okta: 7 problems
# Processed OKX: 3 problems
# Processed Ola Cabs: 2 problems
# Processed OpenAI: 11 problems
# Processed Opendoor: 1 problems
# Processed opentext: 4 problems
# Processed Optiver: 3 problems
# Processed Optum: 6 problems
# Processed Oracle: 100 problems
# Processed Otter.ai: 5 problems
# Processed oyo: 9 problems
# Processed Ozon: 14 problems
# Processed Palantir Technologies: 29 problems
# Processed Palo Alto Networks: 26 problems
# Processed Patreon: 3 problems
# Processed Paycom: 4 problems
# Processed PayPal: 100 problems
# Processed PayPay: 3 problems
# Processed Paytm: 30 problems
# Processed PayU: 2 problems
# Processed peak6: 2 problems
# Processed Peloton: 3 problems
# Processed persistent systems: 10 problems
# Processed PhonePe: 93 problems
# Processed Pinterest: 49 problems
# Processed Pocket Gems: 15 problems
# Processed Point72: 8 problems
# Processed Pony.ai: 4 problems
# Processed PornHub: 9 problems
# Processed Poshmark: 4 problems
# Processed Postmates: 3 problems
# Processed Publicis Sapient: 5 problems
# Processed PubMatic: 3 problems
# Processed Pure Storage: 7 problems
# Processed Pwc: 7 problems
# Processed QBurst: 3 problems
# Processed Qualcomm: 48 problems
# Processed Qualtrics: 3 problems
# Processed Quora: 18 problems
# Processed Rakuten: 6 problems
# Processed razorpay: 10 problems
# Processed RBC: 5 problems
# Processed redbus: 2 problems
# Processed Reddit: 6 problems
# Processed Remitly: 8 problems
# Processed Revolut: 11 problems
# Processed Riot Games: 4 problems
# Processed Ripple: 12 problems
# Processed Rippling: 16 problems
# Processed Rivian: 9 problems
# Processed Robinhood: 15 problems
# Processed Roblox: 53 problems
# Processed Roche: 2 problems
# Processed Rokt: 4 problems
# Processed Roku: 15 problems
# Processed Rubrik: 36 problems
# Processed Salesforce: 100 problems
# Processed Samsara: 6 problems
# Processed Samsung: 73 problems
# Processed SAP: 39 problems
# Processed Scale AI: 2 problems
# Processed Sentry: 2 problems
# Processed ServiceNow: 84 problems
# Processed ShareChat: 2 problems
# Processed Shopee: 10 problems
# Processed Shopify: 8 problems
# Processed Siemens: 25 problems
# Processed SIG: 7 problems
# Processed Sigmoid: 6 problems
# Processed Slice: 2 problems
# Processed smartnews: 5 problems
# Processed Smartsheet: 4 problems
# Processed Snap: 100 problems
# Processed Snapdeal: 3 problems
# Processed Snowflake: 90 problems
# Processed Societe Generale: 2 problems
# Processed SoFi: 18 problems
# Processed Softwire: 3 problems
# Processed Sony: 4 problems
# Processed SOTI: 4 problems
# Processed SoundHound: 3 problems
# Processed Splunk: 14 problems
# Processed Spotify: 13 problems
# Processed Sprinklr: 41 problems
# Processed Squarepoint Capital: 0 problems
# Processed Squarespace: 3 problems
# Processed StackAdapt: 4 problems
# Processed Stackline: 2 problems
# Processed Stripe: 6 problems
# Processed Sumo Logic: 4 problems
# Processed Swiggy: 31 problems
# Processed Synopsys: 2 problems
# Processed Tanium: 1 problems
# Processed Target: 4 problems
# Processed tcs: 100 problems
# Processed Tech Mahindra: 5 problems
# Processed Tejas Networks: 0 problems
# Processed Tekion: 20 problems
# Processed Tencent: 15 problems
# Processed Teradata: 3 problems
# Processed Tesco: 4 problems
# Processed Tesla: 46 problems
# Processed Texas Instruments: 4 problems
# Processed The Trade Desk: 5 problems
# Processed Thomson Reuters: 3 problems
# Processed thoughtspot: 12 problems
# Processed ThoughtWorks: 8 problems
# Processed ThousandEyes: 5 problems
# Processed Tiger Analytics: 4 problems
# Processed TikTok: 100 problems
# Processed Tinder: 2 problems
# Processed Tinkoff: 32 problems
# Processed Toast: 3 problems
# Processed Toptal: 3 problems
# Processed Tower Research Capital: 2 problems
# Processed Trexquant: 5 problems
# Processed Trilogy: 5 problems
# Processed Tripadvisor: 4 problems
# Processed Turing: 41 problems
# Processed Turo: 5 problems
# Processed Turvo: 3 problems
# Processed TuSimple: 4 problems
# Processed Twilio: 13 problems
# Processed Twitch: 8 problems
# Processed Two Sigma: 23 problems
# Processed Uber: 100 problems
# Processed UBS: 5 problems
# Processed UiPath: 10 problems
# Processed UKG: 11 problems
# Processed Unity: 4 problems
# Processed Upstart: 4 problems
# Processed Urban Company: 5 problems
# Processed USAA: 1 problems
# Processed Valve: 4 problems
# Processed Vanguard: 2 problems
# Processed Veeva Systems: 5 problems
# Processed Verily: 12 problems
# Processed Veritas: 2 problems
# Processed Verkada: 15 problems
# Processed Vimeo: 6 problems
# Processed Virtu Financial: 5 problems
# Processed Virtusa: 4 problems
# Processed Visa: 84 problems
# Processed VK: 7 problems
# Processed VMware: 20 problems
# Processed Walmart Labs: 100 problems
# Processed Warnermedia: 10 problems
# Processed WatchGuard: 2 problems
# Processed Wayfair: 24 problems
# Processed Waymo: 10 problems
# Processed Wealthfront: 1 problems
# Processed Wells Fargo: 15 problems
# Processed WeRide: 6 problems
# Processed Western Digital: 1 problems
# Processed Whatnot: 7 problems
# Processed WinZO: 4 problems
# Processed Wipro: 25 problems
# Processed Wise: 5 problems
# Processed Wish: 4 problems
# Processed Wissen Technology: 3 problems
# Processed Wix: 57 problems
# Processed Workday: 8 problems
# Processed Works Applications: 4 problems
# Processed WorldQuant: 4 problems
# Processed X: 52 problems
# Processed Yahoo: 100 problems
# Processed Yandex: 100 problems
# Processed Yelp: 29 problems
# Processed Yext: 4 problems
# Processed Zalando: 6 problems
# Processed Zendesk: 3 problems
# Processed Zenefits: 21 problems
# Processed Zepto: 31 problems
# Processed Zeta: 21 problems
# Processed zeta suite: 3 problems
# Processed Zillow: 3 problems
# Processed ZipRecruiter: 4 problems
# Processed Zluri: 2 problems
# Processed Zoho: 100 problems
# Processed Zomato: 24 problems
# Processed Zoom: 3 problems
# Processed Zoox: 9 problems
# Processed Zopsmart: 18 problems
# Processed ZS Associates: 9 problems
# Processed ZScaler: 24 problems
# Processed Zynga: 4 problems
# Total problems before dedup: 7715
# Creating final result...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4 if not combined_df.empty:
#       5     print(f"Creating final result...")
# ----> 6     final_result = createFinalResult(combined_df)
#       8     print(f"Final result: {len(final_result)} rows")
#      10     # Display sample results
#
# NameError: name 'createFinalResult' is not defined

# %%
# Alternative version with better formatting for companies
def create_final_result_formatted(combined_df):
    """
    Create final result with better formatting
    """
    # Group by Title to get all companies for each problem
    problem_companies = combined_df.groupby('Title')['Company'].apply(
        lambda x: sorted(list(set(x)))  # Sort companies alphabetically
    ).reset_index()
    problem_companies.columns = ['Title', 'Companies']
    
    # Get unique problem details
    unique_problems = combined_df.drop_duplicates(subset=['Title']).copy()
    
    # Merge companies back
    unique_problems = unique_problems.merge(problem_companies, on='Title', how='left')
    
    # Create expanded dataframe for each topic
    final_rows = []
    
    for idx, row in unique_problems.iterrows():
        if pd.notna(row['Topics']):
            topics = [topic.strip() for topic in row['Topics'].split(',')]
            
            for topic in topics:
                final_rows.append({
                    'Problem_Type': topic,
                    'Companies': ', '.join(row['Companies']),  # Join as string
                    'Company_List': row['Companies'],  # Keep as list for analysis
                    'Company_Count': len(row['Companies']),
                    'Title': row['Title'],
                    'Difficulty': row['Difficulty'],
                    'Frequency': row['Frequency'],
                    'Acceptance_Rate': row['Acceptance Rate'],
                    'Link': row['Link']
                })
    
    final_df = pd.DataFrame(final_rows)
    
    # Sort by Problem Type, then by Company Count (descending)
    final_df = final_df.sort_values(['Problem_Type', 'Company_Count', 'Frequency'], 
                                   ascending=[True, False, False])
    
    return final_df

# Usage with formatted version
final_result_formatted = create_final_result_formatted(combined_df)

# %%
# Analysis functions
def analyze_results(final_df):
    """
    Analyze the final results
    """
    print("=== ANALYSIS ===")
    
    # Top problem types by count
    print("\nTop Problem Types:")
    problem_type_counts = final_df['Problem_Type'].value_counts().head(10)
    print(problem_type_counts)
    
    # Problems used by most companies
    print("\nProblems used by most companies:")
    most_popular = final_df.nlargest(10, 'Company_Count')[['Title', 'Problem_Type', 'Company_Count', 'Companies']]
    print(most_popular)
    
    # Company statistics
    print(f"\nTotal unique companies: {len(set([comp for comp_list in final_df['Company_List'] for comp in comp_list]))}")
    print(f"Total unique problems: {final_df['Title'].nunique()}")
    print(f"Total problem-type combinations: {len(final_df)}")

# Run analysis
analyze_results(final_result_formatted)

# %%
# Filter specific results
def filter_by_problem_type(final_df, problem_type):
    """
    Filter results by specific problem type
    """
    filtered = final_df[final_df['Problem_Type'] == problem_type].copy()
    return filtered.sort_values(['Company_Count', 'Frequency'], ascending=[False, False])

# Example: Get all Array problems
array_problems = filter_by_problem_type(final_result_formatted, 'Array')
print("Array Problems:")
print(array_problems[['Title', 'Companies', 'Company_Count', 'Frequency', 'Acceptance_Rate']].head())
